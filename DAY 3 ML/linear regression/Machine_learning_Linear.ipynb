# %% [markdown]
# Machine Learning
# 1. Supervised Learning
# 2. Unsupervised Learning
# 3. Reinforcement Learning

# %%
import pandas as pd
import joblib

# %%
df = pd.read_csv(f"SOCR-HeightWeight.csv")

# %%
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
df.tail()
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742

# %%
df.isnull()
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0      False           False           False
# 1      False           False           False
# 2      False           False           False
# 3      False           False           False
# 4      False           False           False
# ...      ...             ...             ...
# 24995  False           False           False
# 24996  False           False           False
# 24997  False           False           False
# 24998  False           False           False
# 24999  False           False           False
#
# [25000 rows x 3 columns]

# %%
df.isna()
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0      False           False           False
# 1      False           False           False
# 2      False           False           False
# 3      False           False           False
# 4      False           False           False
# ...      ...             ...             ...
# 24995  False           False           False
# 24996  False           False           False
# 24997  False           False           False
# 24998  False           False           False
# 24999  False           False           False
#
# [25000 rows x 3 columns]

# %%
df.isna().count()
# Out:
# Index             25000
# Height(Inches)    25000
# Weight(Pounds)    25000
# dtype: int64

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
x = df[['Height(Inches)']]
x.head()
# Out:
#    Height(Inches)
# 0        65.78331
# 1        71.51521
# 2        69.39874
# 3        68.21660
# 4        67.78781

# %%
y = df['Weight(Pounds)']
y.head()
# Out:
# 0    112.9925
# 1    136.4873
# 2    153.0269
# 3    142.3354
# 4    144.2971
# Name: Weight(Pounds), dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error
from joblib import dump, load

# %% [markdown]
# Splitting the features into 4 components for training and testing
# 0.2 refers to 20% of the test data remaining 80% will be a training data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
lin = LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin.predict(x_test)

# %%
y_pred
# Out:
# array([136.11070945, 136.37690669, 115.97610576, ..., 131.52942807,
#        121.08011231, 120.24655767], shape=(5000,))

# %%
y_test
# Out:
# 18645    140.4445
# 16829    150.7492
# 19760    116.8191
# 13209    129.9965
# 3840     159.8542
#            ...
# 15126    124.6932
# 12335    130.8096
# 6730     145.1667
# 17946    116.4385
# 18679    123.9509
# Name: Weight(Pounds), Length: 5000, dtype: float64

# %%
r = r2_score(y_test, y_pred)
m = mean_absolute_error(y_test, y_pred)

# %%
print(r"r2_score: ",r)
print(r"Mean Absolute error: ", m)
# Out:
# r2_score:  0.25787862377839144
# Mean Absolute error:  8.08006243969202

# %%
dump(lin, "linear.joblib")
# Out:
# ['linear.joblib']

# %% [markdown]
# load data
#
# import packages
#
# split data into X and Y
#
# split them into 4 components as train and test
#
# choose model

# %% [markdown]
# Underfitting is when a model is too simple to capture the data's patterns, while overfitting is when it's too complex and memorizes noise instead of learning general trends.
